# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier

from sklearn.model_selection import KFold, GridSearchCV
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.metrics import make_scorer
from sklearn.impute import SimpleImputer
from scipy.stats import pearsonr

# %%
def fill_missing_values(X, n_neighbors = 75, method="KNN"): 
    
    # normalization
    X_std = np.nanstd(X,axis=0,keepdims=True)
    X_ave = np.nanmean(X,axis=0,keepdims=True)
    X_norma = (X-X_ave)/X_std
    
    # use KNNImputer
    imputer = KNNImputer(missing_values=np.nan, n_neighbors=n_neighbors, weights = 'distance') if method=="KNN"\
        else SimpleImputer(missing_values=np.nan, strategy='median')
    
    X_norma_fixed = imputer.fit_transform(X_norma)
    return X_norma_fixed

def select_features(X, y, X_test, feature_num=200):
    clf = ExtraTreesClassifier(n_jobs=-1, n_estimators=150, random_state=1, min_samples_leaf = 3, min_samples_split=3, max_features = 300)
    clf.fit(X, y)
    indices = np.asarray(list(clf.feature_importances_)).argsort()[-feature_num:][::-1]
    X = np.take(X, indices, axis = 1)
    X_test = np.take(X_test, indices, axis = 1)
    return X, X_test

def expand_dataset(X_train, y_train, num_class = 4):
    sample = np.c_[X_train, y_train]
    sample_by_class = [sample[(sample[:,-1] == i)] for i in range(num_class)]
    sample_sizes = [ sample_class.shape[0] for sample_class in sample_by_class]
    expand_ratio = np.round(np.max(np.array(sample_sizes))/sample_sizes)
    expanded_sample_by_class = [ np.repeat(sample_by_class[i], expand_ratio[i], axis = 0) for i in range(num_class)]
    expanded_sample = np.concatenate(expanded_sample_by_class)
    return expanded_sample[:, :-1], expanded_sample[:, -1]

# %%
X_train_data = pd.read_csv('X_train_feature_fusion2.csv')
y_train_data = pd.read_csv('y_train.csv')
X_test_data = pd.read_csv('X_test_feature_fusion2.csv')

indices_test = np.array(X_test_data)[:,0]
indices_train = np.array(X_train_data)[:,0]
X_test = np.array(X_test_data)[:,1:]
y_train = np.array(y_train_data)[:,1]
X_train = np.array(X_train_data)[:,1:]

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (5117, 692)
# (5117,)
# (3411, 692)

# %%
X_train, X_test = select_features(X_train, y_train, X_test, feature_num = 200)

# %%
class HierarchyClassifier:
    def __init__(self, first_estimator, second_estimator, third_estimator):
        self.first_estimator = first_estimator
        self.second_estimator = second_estimator
        self.third_estimator = third_estimator
        
    def fit(self, X_train, y_train):
        y_train_first = y_train.copy()
        mask = (y_train_first != 3)
        y_train_first [mask] = 1
        y_train_first [~mask] = 0

        X_train_second = X_train[mask]
        y_train_second = y_train[mask].copy()
        second_mask = (y_train_second != 0)
        y_train_second[second_mask] = 1
        
        X_train_third = X_train_second[second_mask]
        y_train_third = y_train[mask][second_mask] - 1
        
        X_train, y_train_first = expand_dataset(X_train, y_train_first, num_class = 2)
        self.first_estimator.fit(X_train, y_train_first)
        
        X_train_second, y_train_second = expand_dataset(X_train_second, y_train_second, num_class = 2)
        self.second_estimator.fit(X_train_second, y_train_second)
        
        X_train_third, y_train_third = expand_dataset(X_train_third, y_train_third, num_class = 2)
        self.third_estimator.fit(X_train_third, y_train_third)
        
    def predict(self, X_test):
        y_pred_first = self.first_estimator.predict(X_test)
        mask = (y_pred_first != 0)
        y_pred_first[~mask] = 3
        
        X_test_second = X_test[mask]
        y_pred_second = self.second_estimator.predict(X_test_second)
        second_mask = (y_pred_second != 0)
        
        X_test_third = X_test_second[second_mask]
        y_pred_third = self.third_estimator.predict(X_test_third) + 1
        
        y_pred_second[second_mask] = y_pred_third
        y_pred_first[mask] = y_pred_second
        
        return y_pred_first
        
    
def fit_model_and_pred(X_train, y_train, X_val, y_val, X_test):
    first_estimator = GradientBoostingClassifier(learning_rate=0.05, n_estimators=500, max_depth=7, 
                                    min_samples_split=60, min_samples_leaf=9, subsample=1,
                                    max_features=50, random_state=0)
    
    second_estimator = GradientBoostingClassifier(learning_rate=0.05, n_estimators=500, max_depth=7, 
                                    min_samples_split=60, min_samples_leaf=9, subsample=1,
                                    max_features=50, random_state=0)
    
    third_estimator = GradientBoostingClassifier(learning_rate=0.05, n_estimators=500, max_depth=7, 
                                    min_samples_split=60, min_samples_leaf=9, subsample=1,
                                    max_features=50, random_state=0)
    # bagging
    clf = HierarchyClassifier(first_estimator, second_estimator, third_estimator)
    clf.fit(X_train, y_train)
    y_val_pred = clf.predict(X_val)
    score = f1_score(y_val, y_val_pred, average='micro')
    y_pred = clf.predict(X_test) 
    return score, y_pred

def train_k_fold(X, y, fold_num=10):
    kf = KFold(n_splits=fold_num, random_state=None, shuffle=False)
    kf.get_n_splits(X)
    test_score = 0.0
    
    for train_index, test_index in kf.split(X):
        X_train, X_val = X[train_index], X[test_index]
        y_train, y_val = y[train_index], y[test_index]

        score, _ = fit_model_and_pred(X_train, y_train, X_val, y_val, X_val)

        print('The obtained validation r1 score is : ',score)
        test_score += score
    print("Validation score: %f"%(test_score/fold_num))

def train_k_fold_pred(X, y, X_test, fold_num=10):
    kf = KFold(n_splits=fold_num, random_state=None, shuffle=True)
    kf.get_n_splits(X)
    test_score = 0.0
    y_pred_list = []
    
    for train_index, test_index in kf.split(X):
        X_train, X_val = X[train_index], X[test_index]
        y_train, y_val = y[train_index], y[test_index]

        score, y_pred = fit_model_and_pred(X_train, y_train, X_val, y_val, X_test)
        y_pred_list.append(y_pred)
        print('The obtained validation r1 score is : ',score)
        test_score += score
    print("Validation score: %f"%(test_score/fold_num))
    
    y_pred_list = np.array(y_pred_list)
    y_test_predict = []
    for i in range(y_pred_list.shape[1]):
        item = y_pred_list[:,i]
        a = item[item==0].shape
        b = item[item==1].shape
        c = item[item==2].shape
        d = item[item==3].shape
        candidate = [a, b, c, d]
        y_test_predict.append(np.argmax(candidate))
    y_test_predict = np.array(y_test_predict)
    return test_score/fold_num, y_test_predict

# %%
y_pred = []
score_list = []
for i in range(100):
    score, y_pred_temp = train_k_fold_pred(X_train, y_train, X_test, fold_num=5) 
    y_pred.append(y_pred_temp)
    score_list.append(score)
# Out:
# The obtained validation r1 score is :  0.822265625
# The obtained validation r1 score is :  0.83203125
# The obtained validation r1 score is :  0.8357771260997068
# The obtained validation r1 score is :  0.8357771260997068
# The obtained validation r1 score is :  0.841642228739003
# Validation score: 0.833499
# The obtained validation r1 score is :  0.8359375
# The obtained validation r1 score is :  0.8427734375
# The obtained validation r1 score is :  0.8592375366568915
# The obtained validation r1 score is :  0.833822091886608
# The obtained validation r1 score is :  0.8220918866080157
# Validation score: 0.838772
# The obtained validation r1 score is :  0.8408203125
# The obtained validation r1 score is :  0.8232421875
# The obtained validation r1 score is :  0.8484848484848486
# The obtained validation r1 score is :  0.8367546432062561
# The obtained validation r1 score is :  0.8387096774193549
# Validation score: 0.837602
# The obtained validation r1 score is :  0.8515625
# The obtained validation r1 score is :  0.8349609375
# The obtained validation r1 score is :  0.8318670576735093
# The obtained validation r1 score is :  0.83088954056696
# The obtained validation r1 score is :  0.8191593352883676
# Validation score: 0.833688
# The obtained validation r1 score is :  0.826171875
# The obtained validation r1 score is :  0.849609375
# The obtained validation r1 score is :  0.844574780058651
# The obtained validation r1 score is :  0.8250244379276638
# The obtained validation r1 score is :  0.8514173998044967
# Validation score: 0.839360
# The obtained validation r1 score is :  0.8369140625
# The obtained validation r1 score is :  0.83203125
# The obtained validation r1 score is :  0.852394916911046
# The obtained validation r1 score is :  0.83088954056696
# The obtained validation r1 score is :  0.8377321603128056
# Validation score: 0.837992
# The obtained validation r1 score is :  0.82421875
# The obtained validation r1 score is :  0.873046875
# The obtained validation r1 score is :  0.8220918866080157
# The obtained validation r1 score is :  0.8220918866080157
# The obtained validation r1 score is :  0.8260019550342131
# Validation score: 0.833490
# The obtained validation r1 score is :  0.82421875
# The obtained validation r1 score is :  0.82421875
# The obtained validation r1 score is :  0.8455522971652004
# The obtained validation r1 score is :  0.852394916911046
# The obtained validation r1 score is :  0.8299120234604106
# Validation score: 0.835259
# The obtained validation r1 score is :  0.8330078125
# The obtained validation r1 score is :  0.8232421875
# The obtained validation r1 score is :  0.8514173998044967
# The obtained validation r1 score is :  0.8279569892473119
# The obtained validation r1 score is :  0.8250244379276638
# Validation score: 0.832130
# The obtained validation r1 score is :  0.8447265625
# The obtained validation r1 score is :  0.810546875
# The obtained validation r1 score is :  0.8357771260997068
# The obtained validation r1 score is :  0.8435972629521017
# The obtained validation r1 score is :  0.8289345063538613
# Validation score: 0.832716
# The obtained validation r1 score is :  0.8291015625
# The obtained validation r1 score is :  0.828125
# The obtained validation r1 score is :  0.8318670576735093
# The obtained validation r1 score is :  0.8494623655913978
# The obtained validation r1 score is :  0.8484848484848486
# Validation score: 0.837408
# The obtained validation r1 score is :  0.841796875
# The obtained validation r1 score is :  0.82421875
# The obtained validation r1 score is :  0.8494623655913978
# The obtained validation r1 score is :  0.8406647116324536
# The obtained validation r1 score is :  0.844574780058651
# Validation score: 0.840143
# The obtained validation r1 score is :  0.84375
# The obtained validation r1 score is :  0.8466796875
# The obtained validation r1 score is :  0.8504398826979471
# The obtained validation r1 score is :  0.8279569892473119
# The obtained validation r1 score is :  0.8260019550342131
# Validation score: 0.838966
# The obtained validation r1 score is :  0.8525390625
# The obtained validation r1 score is :  0.8369140625
# The obtained validation r1 score is :  0.8347996089931574
# The obtained validation r1 score is :  0.8494623655913978
# The obtained validation r1 score is :  0.8103616813294232
# Validation score: 0.836815
# The obtained validation r1 score is :  0.837890625
# The obtained validation r1 score is :  0.8349609375
# The obtained validation r1 score is :  0.8367546432062561
# The obtained validation r1 score is :  0.8318670576735093
# The obtained validation r1 score is :  0.8289345063538613
# Validation score: 0.834082
# The obtained validation r1 score is :  0.84765625
# The obtained validation r1 score is :  0.8095703125
# The obtained validation r1 score is :  0.8318670576735093
# The obtained validation r1 score is :  0.8328445747800586
# The obtained validation r1 score is :  0.844574780058651
# Validation score: 0.833303
# The obtained validation r1 score is :  0.849609375
# The obtained validation r1 score is :  0.8271484375
# The obtained validation r1 score is :  0.8396871945259042
# The obtained validation r1 score is :  0.8084066471163246
# The obtained validation r1 score is :  0.855327468230694
# Validation score: 0.836036
# The obtained validation r1 score is :  0.8427734375
# The obtained validation r1 score is :  0.8525390625
# The obtained validation r1 score is :  0.8162267839687195
# The obtained validation r1 score is :  0.8260019550342131
# The obtained validation r1 score is :  0.8269794721407625
# Validation score: 0.832904
# The obtained validation r1 score is :  0.8212890625
# The obtained validation r1 score is :  0.8330078125
# The obtained validation r1 score is :  0.8347996089931574
# The obtained validation r1 score is :  0.8279569892473119
# The obtained validation r1 score is :  0.844574780058651
# Validation score: 0.832326
# The obtained validation r1 score is :  0.83984375
# The obtained validation r1 score is :  0.82421875
# The obtained validation r1 score is :  0.8211143695014664
# The obtained validation r1 score is :  0.8533724340175953
# The obtained validation r1 score is :  0.8396871945259042
# Validation score: 0.835647
# The obtained validation r1 score is :  0.8291015625
# The obtained validation r1 score is :  0.833984375
# The obtained validation r1 score is :  0.8260019550342131
# The obtained validation r1 score is :  0.8465298142717498
# The obtained validation r1 score is :  0.8494623655913978
# Validation score: 0.837016
# The obtained validation r1 score is :  0.85546875
# The obtained validation r1 score is :  0.818359375
# The obtained validation r1 score is :  0.8269794721407625
# The obtained validation r1 score is :  0.8299120234604106
# The obtained validation r1 score is :  0.8347996089931574
# Validation score: 0.833104
# The obtained validation r1 score is :  0.8427734375
# The obtained validation r1 score is :  0.84375
# The obtained validation r1 score is :  0.8465298142717498
# The obtained validation r1 score is :  0.8387096774193549
# The obtained validation r1 score is :  0.820136852394917
# Validation score: 0.838380
# The obtained validation r1 score is :  0.8515625
# The obtained validation r1 score is :  0.841796875
# The obtained validation r1 score is :  0.8347996089931574
# The obtained validation r1 score is :  0.823069403714565
# The obtained validation r1 score is :  0.8377321603128056
# Validation score: 0.837792
# The obtained validation r1 score is :  0.826171875
# The obtained validation r1 score is :  0.8349609375
# The obtained validation r1 score is :  0.8279569892473119
# The obtained validation r1 score is :  0.8475073313782991
# The obtained validation r1 score is :  0.8396871945259042
# Validation score: 0.835257
# The obtained validation r1 score is :  0.8251953125
# The obtained validation r1 score is :  0.8486328125
# The obtained validation r1 score is :  0.820136852394917
# The obtained validation r1 score is :  0.841642228739003
# The obtained validation r1 score is :  0.8465298142717498
# Validation score: 0.836427
# The obtained validation r1 score is :  0.8330078125
# The obtained validation r1 score is :  0.833984375
# The obtained validation r1 score is :  0.8475073313782991
# The obtained validation r1 score is :  0.8074291300097751
# The obtained validation r1 score is :  0.833822091886608
# Validation score: 0.831150
# The obtained validation r1 score is :  0.8330078125
# The obtained validation r1 score is :  0.845703125
# The obtained validation r1 score is :  0.8484848484848486
# The obtained validation r1 score is :  0.8435972629521017
# The obtained validation r1 score is :  0.8289345063538613
# Validation score: 0.839946
# The obtained validation r1 score is :  0.8486328125
# The obtained validation r1 score is :  0.8203125
# The obtained validation r1 score is :  0.8299120234604106
# The obtained validation r1 score is :  0.8240469208211144
# The obtained validation r1 score is :  0.833822091886608
# Validation score: 0.831345
# The obtained validation r1 score is :  0.86328125
# The obtained validation r1 score is :  0.8212890625
# The obtained validation r1 score is :  0.841642228739003
# The obtained validation r1 score is :  0.823069403714565
# The obtained validation r1 score is :  0.8260019550342131
# Validation score: 0.835057
# The obtained validation r1 score is :  0.8203125
# The obtained validation r1 score is :  0.8466796875
# The obtained validation r1 score is :  0.83088954056696
# The obtained validation r1 score is :  0.8328445747800586
# The obtained validation r1 score is :  0.8484848484848486
# Validation score: 0.835842
# The obtained validation r1 score is :  0.8427734375
# The obtained validation r1 score is :  0.8505859375
# The obtained validation r1 score is :  0.8406647116324536
# The obtained validation r1 score is :  0.83088954056696
# The obtained validation r1 score is :  0.841642228739003
# Validation score: 0.841311
# The obtained validation r1 score is :  0.8369140625
# The obtained validation r1 score is :  0.8173828125
# The obtained validation r1 score is :  0.841642228739003
# The obtained validation r1 score is :  0.8318670576735093
# The obtained validation r1 score is :  0.844574780058651
# Validation score: 0.834476
# The obtained validation r1 score is :  0.833984375
# The obtained validation r1 score is :  0.8515625
# The obtained validation r1 score is :  0.8377321603128056
# The obtained validation r1 score is :  0.8289345063538613
# The obtained validation r1 score is :  0.8426197458455523
# Validation score: 0.838967
# The obtained validation r1 score is :  0.8388671875
# The obtained validation r1 score is :  0.818359375
# The obtained validation r1 score is :  0.8318670576735093
# The obtained validation r1 score is :  0.8387096774193549
# The obtained validation r1 score is :  0.8387096774193549
# Validation score: 0.833303
# The obtained validation r1 score is :  0.8408203125
# The obtained validation r1 score is :  0.8369140625
# The obtained validation r1 score is :  0.844574780058651
# The obtained validation r1 score is :  0.8426197458455523
# The obtained validation r1 score is :  0.820136852394917
# Validation score: 0.837013
# The obtained validation r1 score is :  0.828125
# The obtained validation r1 score is :  0.857421875
# The obtained validation r1 score is :  0.83088954056696
# The obtained validation r1 score is :  0.8426197458455523
# The obtained validation r1 score is :  0.8250244379276638
# Validation score: 0.836816
# The obtained validation r1 score is :  0.837890625
# The obtained validation r1 score is :  0.8466796875
# The obtained validation r1 score is :  0.8484848484848486
# The obtained validation r1 score is :  0.833822091886608
# The obtained validation r1 score is :  0.8328445747800586
# Validation score: 0.839944
# The obtained validation r1 score is :  0.8486328125
# The obtained validation r1 score is :  0.8310546875
# The obtained validation r1 score is :  0.8211143695014664
# The obtained validation r1 score is :  0.8435972629521017
# The obtained validation r1 score is :  0.8279569892473119
# Validation score: 0.834471
# The obtained validation r1 score is :  0.818359375
# The obtained validation r1 score is :  0.8408203125
# The obtained validation r1 score is :  0.8357771260997068
# The obtained validation r1 score is :  0.8152492668621701
# The obtained validation r1 score is :  0.8377321603128056
# Validation score: 0.829588
# The obtained validation r1 score is :  0.8544921875
# The obtained validation r1 score is :  0.841796875
# The obtained validation r1 score is :  0.8377321603128056
# The obtained validation r1 score is :  0.8142717497556208
# The obtained validation r1 score is :  0.83088954056696
# Validation score: 0.835837
# The obtained validation r1 score is :  0.841796875
# The obtained validation r1 score is :  0.82421875
# The obtained validation r1 score is :  0.833822091886608
# The obtained validation r1 score is :  0.8387096774193549
# The obtained validation r1 score is :  0.833822091886608
# Validation score: 0.834474
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/df/qjssdfqd3f52ltwv16hkg4kh0000gn/T/ipykernel_21386/4202445105.py in <module>
#       2 score_list = []
#       3 for i in range(100):
# ----> 4     score, y_pred_temp = train_k_fold_pred(X_train, y_train, X_test, fold_num=5)
#       5     y_pred.append(y_pred_temp)
#       6     score_list.append(score)
#
# /var/folders/df/qjssdfqd3f52ltwv16hkg4kh0000gn/T/ipykernel_21386/2287918438.py in train_k_fold_pred(X, y, X_test, fold_num)
#      91         y_train, y_val = y[train_index], y[test_index]
#      92
# ---> 93         score, y_pred = fit_model_and_pred(X_train, y_train, X_val, y_val, X_test)
#      94         y_pred_list.append(y_pred)
#      95         print('The obtained validation r1 score is : ',score)
#
# /var/folders/df/qjssdfqd3f52ltwv16hkg4kh0000gn/T/ipykernel_21386/2287918438.py in fit_model_and_pred(X_train, y_train, X_val, y_val, X_test)
#      60     # bagging
#      61     clf = HierarchyClassifier(first_estimator, second_estimator, third_estimator)
# ---> 62     clf.fit(X_train, y_train)
#      63     y_val_pred = clf.predict(X_val)
#      64     score = f1_score(y_val, y_val_pred, average='micro')
#
# /var/folders/df/qjssdfqd3f52ltwv16hkg4kh0000gn/T/ipykernel_21386/2287918438.py in fit(self, X_train, y_train)
#      23
#      24         X_train_second, y_train_second = expand_dataset(X_train_second, y_train_second, num_class = 2)
# ---> 25         self.second_estimator.fit(X_train_second, y_train_second)
#      26
#      27         X_train_third, y_train_third = expand_dataset(X_train_third, y_train_third, num_class = 2)
#
# ~/anaconda3/envs/aml_project/lib/python3.8/site-packages/sklearn/ensemble/_gb.py in fit(self, X, y, sample_weight, monitor)
#     502
#     503         # fit the boosting stages
# --> 504         n_stages = self._fit_stages(
#     505             X, y, raw_predictions, sample_weight, self._rng, X_val, y_val,
#     506             sample_weight_val, begin_at_stage, monitor)
#
# ~/anaconda3/envs/aml_project/lib/python3.8/site-packages/sklearn/ensemble/_gb.py in _fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     559
#     560             # fit next stage of trees
# --> 561             raw_predictions = self._fit_stage(
#     562                 i, X, y, raw_predictions, sample_weight, sample_mask,
#     563                 random_state, X_csc, X_csr)
#
# ~/anaconda3/envs/aml_project/lib/python3.8/site-packages/sklearn/ensemble/_gb.py in _fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     216
#     217             # update tree leaves
# --> 218             loss.update_terminal_regions(
#     219                 tree.tree_, X, y, residual, raw_predictions, sample_weight,
#     220                 sample_mask, learning_rate=self.learning_rate, k=k)
#
# ~/anaconda3/envs/aml_project/lib/python3.8/site-packages/sklearn/ensemble/_gb_losses.py in update_terminal_regions(self, tree, X, y, residual, raw_predictions, sample_weight, sample_mask, learning_rate, k)
#     110         # update each leaf (= perform line search)
#     111         for leaf in np.where(tree.children_left == TREE_LEAF)[0]:
# --> 112             self._update_terminal_region(tree, masked_terminal_regions,
#     113                                          leaf, X, y, residual,
#     114                                          raw_predictions[:, k], sample_weight)
#
# ~/anaconda3/envs/aml_project/lib/python3.8/site-packages/sklearn/ensemble/_gb_losses.py in _update_terminal_region(self, tree, terminal_regions, leaf, X, y, residual, raw_predictions, sample_weight)
#     625         numerator = np.sum(sample_weight * residual)
#     626         denominator = np.sum(sample_weight *
# --> 627                              (y - residual) * (1 - y + residual))
#     628
#     629         # prevents overflow and division by zero
#
# KeyboardInterrupt:

# %%
score_list = np.array(score_list)
print(np.mean(score_list))
print(np.median(score_list))
print(np.min(score_list))
print(np.max(score_list))
print(np.std(score_list))
# Out:
# 0.8357060624607249
# 0.8357419011180353
# 0.8295876481549366
# 0.8413111711876834
# 0.002756983084384802

# %%
y_pred = np.array(y_pred)
y_pred.shape
# Out:
# (42, 3411)

# %%
np.where(score_list>0.840143)
# Out:
# (array([11, 31]),)

# %%
trick_bar = 0.833
y_pred_list = y_pred[score_list > trick_bar]
print(y_pred_list.shape)
print(np.mean(score_list[score_list > trick_bar]))
# Out:
# (35, 3411)
# 0.8364998723554672

# %%
np.savetxt('result_list.csv', y_pred, delimiter=',')
np.savetxt('score_list.csv', score_list, delimiter=',')

# %%
y_test_predict = []
for i in range(y_pred_list.shape[1]):
    item = y_pred_list[:,i]
    a = item[item==0].shape
    b = item[item==1].shape
    c = item[item==2].shape
    d = item[item==3].shape 
    candidate = [a, b, c, d]
    y_test_predict.append(np.argmax(candidate))
y_test_predict = np.array(y_test_predict)

# %%
sample =  pd.read_csv("sample.csv")
sample["y"] = y_test_predict
sample.to_csv("output_hierarchy_extra.csv", index = False)
