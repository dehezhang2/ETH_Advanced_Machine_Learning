# %%
import numpy as np
import pandas as pd

from sklearn.impute import (SimpleImputer,KNNImputer)
from sklearn.ensemble import (RandomForestRegressor, IsolationForest)
from sklearn.neighbors import LocalOutlierFactor

from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split

import lightgbm as lgb

from sklearn.metrics import r2_score

import warnings
warnings.filterwarnings('ignore')


import skopt


# %matplotlib inline

# %%
def fill_missing_values(X, n_neighbors = 75, method="KNN"): 
    
    # normalization
    X_std = np.nanstd(X,axis=0,keepdims=True)
    X_ave = np.nanmean(X,axis=0,keepdims=True)
    X_norma = (X-X_ave)/X_std
    
    # use KNNImputer
    imputer = KNNImputer(missing_values=np.nan, n_neighbors=n_neighbors, weights = 'distance') if method=="KNN"\
        else SimpleImputer(missing_values=np.nan, strategy='median')
    
    X_norma_fixed = imputer.fit_transform(X_norma)
    
    return X_norma_fixed

def remove_outliers(X, y):
    print("IsolationForest-Traing data shape before removed: {}".format(X.shape))
    Z = np.c_[X, y]
    iforest = IsolationForest(max_samples=200, random_state=1, contamination=0.005)
    iforest.fit(Z)
    iforest_outlier_pred = iforest.predict(Z)
    
    Z = np.c_[X, y]
    local = LocalOutlierFactor(n_neighbors=150, contamination=0.005)
    local.fit(Z)
    local_outlier_pred = local.fit_predict(Z)

    mask = np.logical_and((iforest_outlier_pred!=-1), (local_outlier_pred!=-1))
    X , y = X[mask, :], y[mask]
    print("IsolationForest-Traing data shape after removed: {}".format(X.shape))
    return X, y

def select_features(X, y, X_test, feature_num=50):
    rf = RandomForestRegressor(n_jobs=-1, n_estimators=80, random_state=1)
    rf.fit(X, y)
    indices = np.asarray(list(rf.feature_importances_)).argsort()[-feature_num:][::-1]
    
    X = np.take(X, indices, axis = 1)
    X_test = np.take(X_test, indices, axis = 1)
    return X, X_test

# %%
X_train_data = pd.read_csv('X_train.csv')
y_train_data = pd.read_csv('y_train.csv')
X_test_data = pd.read_csv('X_test.csv')

indices_test = np.array(X_test_data)[:,0]
X_test = np.array(X_test_data)[:,1:]
y_train = np.array(y_train_data)[:,1]
X_train = np.array(X_train_data)[:,1:]

# %% [markdown]
# ## 1. Imputation of Missing Values
# * [Reference](https://scikit-learn.org/stable/modules/impute.html)
# * We use median of column instead of mean

# %%
X_train_missing_indices = X_train[X_train==np]
X_train = fill_missing_values(X_train, n_neighbors=75)
X_test = fill_missing_values(X_test)
print(X_train.shape)
print(X_test.shape)
# Out:
# (1212, 828)
# (776, 828)

# %% [markdown]
# ## 2. Outlier Detection
# * [reference_sklearn](https://scikit-learn.org/stable/modules/outlier_detection.html)
# * [reference_in_detail](https://practicaldatascience.co.uk/machine-learning/how-to-use-the-isolation-forest-model-for-outlier-detection)

# %%
X_train,y_train = remove_outliers(X_train,y_train)
# Out:
# IsolationForest-Traing data shape before removed: (1212, 828)
# IsolationForest-Traing data shape after removed: (1199, 828)

# %% [markdown]
# ## 3. Feature Selection

# %%
X_train, X_test = select_features(X_train, y_train, X_test,feature_num = 50)
print("Traing data shape after selection: {}".format(X_train.shape))
print("Testing data shape after selection: {}".format(X_test.shape))
# Out:
# Traing data shape after selection: (1199, 50)
# Testing data shape after selection: (776, 50)

# %% [markdown]
# ## 4. LGB

# %%
def custom_r2(prediction, train_data):
    """Regular r2 cost function returned as a tuple to be used with lgb"""
    labels = train_data.get_label()
    return 'r2', r2_score(labels, prediction), True

FIXED_PARAMS={
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'verbose': -1,
}
SEARCH_PARAMS = {
    # overfitting
    'lambda_l1':0.0,
    'lambda_l2':0.0,
    # control the model complexity
    'num_leaves': 1700,
    'max_depth': 11,
    # randomly select feature to be used for each round
    'feature_fraction': 0.5,
    # percentage of rows used per tree building iteration
    'subsample': 0.8,
    # Small max_bin causes faster speed and large value improves accuracy
    'max_bin':255,
    # recommended to use smaller learning rate with larger iteration
    'learning_rate': 0.025,
    'num_iterations':600,
    # Start with a lower number of trees to build a baseline and increase it later
    'n_estimators': 1000,
        
    'min_child_weight': 1,
    'colsample_bytree': 0.8,
        
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
}
    

def fit_model_and_pred(X_train, y_train, X_val, y_val, X_test, params):

    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_eval = lgb.Dataset(X_val, y_val, reference=lgb_train)
    
    gbm = lgb.train(params,
                    lgb_train,
                    num_boost_round=params['num_iterations'],
                    feval=custom_r2,
                    valid_sets={lgb_train, lgb_eval},
                    early_stopping_rounds=params['num_iterations']//10,
                    verbose_eval=False
                   )
    
    y_val_pred = gbm.predict(X_val)
    score = r2_score(y_val, y_val_pred)
    y_pred = gbm.predict(X_test) 
    
    return score, y_pred

def train_k_fold(X, y, search_params, fold_num=10):
    kf = KFold(n_splits=fold_num, random_state=None, shuffle=False)
    kf.get_n_splits(X)
    test_score = 0.0
    params = {
        'task': FIXED_PARAMS['task'],
        'boosting_type': FIXED_PARAMS['boosting_type'],
        'objective': FIXED_PARAMS['objective'],
        'verbose': FIXED_PARAMS['verbose'],
        **search_params
    }
    for train_index, test_index in kf.split(X):
        X_train, X_val = X[train_index], X[test_index]
        y_train, y_val = y[train_index], y[test_index]

        score, y_pred = fit_model_and_pred(X_train, y_train, X_val, y_val, X_val, params)
        test_score += score
    print('The obtained validation r2 score is : ',test_score/fold_num)
    return test_score/fold_num

# %%
SPACE = [
    skopt.space.Real(0.01, 0.05, name='lambda_l1', prior='log-uniform'),
    skopt.space.Real(0.01, 0.05, name='lambda_l2', prior='log-uniform'),
    skopt.space.Real(0.4, 0.6, name='feature_fraction', prior='log-uniform'),
    skopt.space.Real(0.7, 0.9, name='subsample', prior='log-uniform'),
    skopt.space.Real(0.01, 0.05, name='learning_rate', prior='log-uniform'),
    
    skopt.space.Integer(1600, 1800, name='num_leaves', prior='uniform'),
    skopt.space.Integer(8, 14, name='max_depth', prior='uniform'),
    skopt.space.Integer(400, 1000, name='num_iterations', prior='uniform'),
    skopt.space.Integer(700, 1300, name='n_estimators', prior='uniform'),

]
@skopt.utils.use_named_args(SPACE)
def objective(**params):
   return -1.0 * train_k_fold(X_train, y_train, params)

results = skopt.forest_minimize(objective, SPACE, 
                                n_calls=1000, n_random_starts=10,)
# Out:
# The obtained validation r2 score is :  0.6258885111157608
# The obtained validation r2 score is :  0.6337959358946312
# The obtained validation r2 score is :  0.6320824100468916
# The obtained validation r2 score is :  0.6253049549416712
# The obtained validation r2 score is :  0.630025337741556
# The obtained validation r2 score is :  0.6258414492909632
# The obtained validation r2 score is :  0.6328355159791341
# The obtained validation r2 score is :  0.6293513422387409
# The obtained validation r2 score is :  0.63425587387056
# The obtained validation r2 score is :  0.6331769641517645
# The obtained validation r2 score is :  0.6302406338721571
# The obtained validation r2 score is :  0.6312758305537515
# The obtained validation r2 score is :  0.6276730953190339
# The obtained validation r2 score is :  0.6335099600425739
# The obtained validation r2 score is :  0.6295828789325556
# The obtained validation r2 score is :  0.631092529134732
# The obtained validation r2 score is :  0.6295345585620542
# The obtained validation r2 score is :  0.6293655029460361
# The obtained validation r2 score is :  0.6322839562172008
# The obtained validation r2 score is :  0.6280937659136798
# The obtained validation r2 score is :  0.6311224123500164
# The obtained validation r2 score is :  0.6305316458335221
# The obtained validation r2 score is :  0.6290161685265709
# The obtained validation r2 score is :  0.6313189212880757
# The obtained validation r2 score is :  0.634984786349774
# The obtained validation r2 score is :  0.6270005225504446
# The obtained validation r2 score is :  0.6295284987373934
# The obtained validation r2 score is :  0.6331647361383358
# The obtained validation r2 score is :  0.6285966957685301
# The obtained validation r2 score is :  0.6292475859156627
# The obtained validation r2 score is :  0.6317078256689592
# The obtained validation r2 score is :  0.6324999330594938
# The obtained validation r2 score is :  0.6367313508032972
# The obtained validation r2 score is :  0.6347476474339973
# The obtained validation r2 score is :  0.62980372764082
# The obtained validation r2 score is :  0.6339129239416412
# The obtained validation r2 score is :  0.6345286979315595
# The obtained validation r2 score is :  0.6330380002995464
# The obtained validation r2 score is :  0.6379529704702375
# The obtained validation r2 score is :  0.6334286646287268
# The obtained validation r2 score is :  0.6352194769711714
# The obtained validation r2 score is :  0.6323131739259665
# The obtained validation r2 score is :  0.6358696138626279
# The obtained validation r2 score is :  0.6326101768126227
# The obtained validation r2 score is :  0.6353285194843876
# The obtained validation r2 score is :  0.6335275720023409
# The obtained validation r2 score is :  0.6315821823172652
# The obtained validation r2 score is :  0.6332140201477225
# The obtained validation r2 score is :  0.6314701428609322
# The obtained validation r2 score is :  0.6324291468714716
# The obtained validation r2 score is :  0.6346459840437878
# The obtained validation r2 score is :  0.632582730032986
# The obtained validation r2 score is :  0.6339861750274405
# The obtained validation r2 score is :  0.633870895472266
# The obtained validation r2 score is :  0.6340068331709646
# The obtained validation r2 score is :  0.6283688455127627
# The obtained validation r2 score is :  0.6281757523810418
# The obtained validation r2 score is :  0.6269930712223912
# The obtained validation r2 score is :  0.6318911864556208
# The obtained validation r2 score is :  0.6303489083994154
# The obtained validation r2 score is :  0.6323830150081344
# The obtained validation r2 score is :  0.6274338031312003
# The obtained validation r2 score is :  0.6357520125788851
# The obtained validation r2 score is :  0.6296381818018725
# The obtained validation r2 score is :  0.6325733149802119
# The obtained validation r2 score is :  0.6308986122180393
# The obtained validation r2 score is :  0.6312105722977555
# The obtained validation r2 score is :  0.6316575249698481
# The obtained validation r2 score is :  0.6356116620339851
# The obtained validation r2 score is :  0.6359968851441928
# The obtained validation r2 score is :  0.6307991755990736
# The obtained validation r2 score is :  0.6313617986674548
# The obtained validation r2 score is :  0.6364895879025918
# The obtained validation r2 score is :  0.633398750771064
# The obtained validation r2 score is :  0.6351413235889921
# The obtained validation r2 score is :  0.6282540104458704
# The obtained validation r2 score is :  0.632574479794467
# The obtained validation r2 score is :  0.632158231231992
# The obtained validation r2 score is :  0.63468927979476
# The obtained validation r2 score is :  0.6300479800246205
# The obtained validation r2 score is :  0.634124823872835
# The obtained validation r2 score is :  0.6341398558241848
# The obtained validation r2 score is :  0.6347966207794936
# The obtained validation r2 score is :  0.6320757498024414
# The obtained validation r2 score is :  0.6348097721796356
# The obtained validation r2 score is :  0.6326375148318492
# The obtained validation r2 score is :  0.6338545900015831
# The obtained validation r2 score is :  0.6326148460776025
# The obtained validation r2 score is :  0.6267240253800891
# The obtained validation r2 score is :  0.627107175356211
# The obtained validation r2 score is :  0.6334561442499438
# The obtained validation r2 score is :  0.6334193389979458
# The obtained validation r2 score is :  0.6346472946760924
# The obtained validation r2 score is :  0.6307617216395425
# The obtained validation r2 score is :  0.6346234723408175
# The obtained validation r2 score is :  0.6277027837699997
# The obtained validation r2 score is :  0.6295245409353493
# The obtained validation r2 score is :  0.6357738844860712
# The obtained validation r2 score is :  0.633328870251664
# The obtained validation r2 score is :  0.6364416907016732
# The obtained validation r2 score is :  0.6331713873299163
# The obtained validation r2 score is :  0.6283717678654192
# The obtained validation r2 score is :  0.6332418687422423
# The obtained validation r2 score is :  0.632271466147657
# The obtained validation r2 score is :  0.6321131632929625
# The obtained validation r2 score is :  0.6257293725535724
# The obtained validation r2 score is :  0.6295751489569887
# The obtained validation r2 score is :  0.6303870479481939
# The obtained validation r2 score is :  0.633256368958392
# The obtained validation r2 score is :  0.6335737413361245
# The obtained validation r2 score is :  0.6286971126467543
# The obtained validation r2 score is :  0.6320113066962232
# The obtained validation r2 score is :  0.633020659138108
# The obtained validation r2 score is :  0.625900852306103
# The obtained validation r2 score is :  0.6264575892077071
# The obtained validation r2 score is :  0.6311082494134096
# The obtained validation r2 score is :  0.6290237959917817
# The obtained validation r2 score is :  0.6332557954447607
# The obtained validation r2 score is :  0.6359361428516123
# The obtained validation r2 score is :  0.6296805078421068
# The obtained validation r2 score is :  0.627740706138826
# The obtained validation r2 score is :  0.6319694178794395
# The obtained validation r2 score is :  0.6308606753729267
# The obtained validation r2 score is :  0.6310697749396967
# The obtained validation r2 score is :  0.6233747835378246
# The obtained validation r2 score is :  0.6350018296938172
# The obtained validation r2 score is :  0.6325906314357133
# The obtained validation r2 score is :  0.6286022144892474
# The obtained validation r2 score is :  0.6262018385827438
# The obtained validation r2 score is :  0.6326195958440929
# The obtained validation r2 score is :  0.6328269432133691
# The obtained validation r2 score is :  0.6293645081540304
# The obtained validation r2 score is :  0.6341739489909071
# The obtained validation r2 score is :  0.6355412054612205
# The obtained validation r2 score is :  0.6304678968570434
# The obtained validation r2 score is :  0.6288310696039459
# The obtained validation r2 score is :  0.6335735865031152
# The obtained validation r2 score is :  0.6326974154925189
# The obtained validation r2 score is :  0.6313630338153808
# The obtained validation r2 score is :  0.6337551063945396
# The obtained validation r2 score is :  0.6312929858756539
# The obtained validation r2 score is :  0.628305994991088
# The obtained validation r2 score is :  0.6333737897972211
# The obtained validation r2 score is :  0.6272496358221242
# The obtained validation r2 score is :  0.6297362092956241
# The obtained validation r2 score is :  0.6288378379428846
# The obtained validation r2 score is :  0.6264593355823923
# The obtained validation r2 score is :  0.632197109983927
# The obtained validation r2 score is :  0.6276759868137092
# The obtained validation r2 score is :  0.6274302154843755
# The obtained validation r2 score is :  0.6341499819935008
# The obtained validation r2 score is :  0.6372053831979758
# The obtained validation r2 score is :  0.6302143703623322
# The obtained validation r2 score is :  0.6312428311064844
# The obtained validation r2 score is :  0.6253578700442541
# The obtained validation r2 score is :  0.6284009438785662
# The obtained validation r2 score is :  0.6336175126484572
# The obtained validation r2 score is :  0.6360407601035758
# The obtained validation r2 score is :  0.6343284674133634
# The obtained validation r2 score is :  0.6299854476962159
# The obtained validation r2 score is :  0.6293590818701403
# The obtained validation r2 score is :  0.6280923058385699
# The obtained validation r2 score is :  0.6351289495343807
# The obtained validation r2 score is :  0.6260219871046964
# The obtained validation r2 score is :  0.6320484138293654
# The obtained validation r2 score is :  0.6341896744593034
# The obtained validation r2 score is :  0.6296371945878202
# The obtained validation r2 score is :  0.635419110240826
# The obtained validation r2 score is :  0.6312056895671121
# The obtained validation r2 score is :  0.6310407756160687
# The obtained validation r2 score is :  0.6292631118581091
# The obtained validation r2 score is :  0.6342586205942766
# The obtained validation r2 score is :  0.633352575623867
# The obtained validation r2 score is :  0.630780209000547
# The obtained validation r2 score is :  0.6287019430518704
# The obtained validation r2 score is :  0.6371292632794641
# The obtained validation r2 score is :  0.6321084040322862
# The obtained validation r2 score is :  0.628019026902737
# The obtained validation r2 score is :  0.629426715223319
# The obtained validation r2 score is :  0.631449935404697
# The obtained validation r2 score is :  0.6331795822136762
# The obtained validation r2 score is :  0.6353411727288242
# The obtained validation r2 score is :  0.6349357273599565
# The obtained validation r2 score is :  0.6316575776607941
# The obtained validation r2 score is :  0.6310112036332495
# The obtained validation r2 score is :  0.6274032250382243
# The obtained validation r2 score is :  0.629765505018414
# The obtained validation r2 score is :  0.6348711831548688
# The obtained validation r2 score is :  0.6298014066995787
# The obtained validation r2 score is :  0.6329396561216013
# The obtained validation r2 score is :  0.6328132403901359
# The obtained validation r2 score is :  0.6349076835839891
# The obtained validation r2 score is :  0.6356449467439899
# The obtained validation r2 score is :  0.6333688671014903
# The obtained validation r2 score is :  0.6337764310862237
# The obtained validation r2 score is :  0.6315965904389004
# The obtained validation r2 score is :  0.6291994485368895
# The obtained validation r2 score is :  0.6322260598464086
# The obtained validation r2 score is :  0.6329735136045765
# The obtained validation r2 score is :  0.6291468608827927
# The obtained validation r2 score is :  0.6332605453439722
# The obtained validation r2 score is :  0.6271020184303471
# The obtained validation r2 score is :  0.6346494285628339
# The obtained validation r2 score is :  0.6329020871057022
# The obtained validation r2 score is :  0.6282875856238956
# The obtained validation r2 score is :  0.6295864882714232
# The obtained validation r2 score is :  0.6259197136513436
# The obtained validation r2 score is :  0.6342417888277023
# The obtained validation r2 score is :  0.6332642284285013
# The obtained validation r2 score is :  0.6272833826920393
# The obtained validation r2 score is :  0.6279275672667032
# The obtained validation r2 score is :  0.6308093169421375
# The obtained validation r2 score is :  0.6303207851180741
# The obtained validation r2 score is :  0.635213066334521
# The obtained validation r2 score is :  0.6369602264252865
# The obtained validation r2 score is :  0.6288796057541857
# The obtained validation r2 score is :  0.6318060440729997
# The obtained validation r2 score is :  0.6325475271440425
# The obtained validation r2 score is :  0.6397811435165758
# The obtained validation r2 score is :  0.6343160588295109
# The obtained validation r2 score is :  0.6333352145140236
# The obtained validation r2 score is :  0.6378568125284291
# The obtained validation r2 score is :  0.6336573998092093
# The obtained validation r2 score is :  0.6321331762200526
# The obtained validation r2 score is :  0.6316227432541803
# The obtained validation r2 score is :  0.6331466854903518
# The obtained validation r2 score is :  0.6317320622426578
# The obtained validation r2 score is :  0.6324445254449029
# The obtained validation r2 score is :  0.6261303785039052
# The obtained validation r2 score is :  0.6312647331737887
# The obtained validation r2 score is :  0.6340607622621891
# The obtained validation r2 score is :  0.6331818216350837
# The obtained validation r2 score is :  0.6349514971862275
# The obtained validation r2 score is :  0.6328658574459617
# The obtained validation r2 score is :  0.6322719455547375
# The obtained validation r2 score is :  0.6339509964851044
# The obtained validation r2 score is :  0.6314218873300773
# The obtained validation r2 score is :  0.6293887471771156
# The obtained validation r2 score is :  0.6334298655934961
# The obtained validation r2 score is :  0.6336916326978906
# The obtained validation r2 score is :  0.6335168935646738
# The obtained validation r2 score is :  0.6278471051185883
# The obtained validation r2 score is :  0.6286847025676471
# The obtained validation r2 score is :  0.6336985274392022
# The obtained validation r2 score is :  0.6287417480056847
# The obtained validation r2 score is :  0.6337209557102865
# The obtained validation r2 score is :  0.6332990394983466
# The obtained validation r2 score is :  0.6323054293807377
# The obtained validation r2 score is :  0.6287708263527221
# The obtained validation r2 score is :  0.6269547377643238
# The obtained validation r2 score is :  0.633254031693515
# The obtained validation r2 score is :  0.6305580025217221
# The obtained validation r2 score is :  0.6334722768049283
# The obtained validation r2 score is :  0.6341780673987474
# The obtained validation r2 score is :  0.6321557227117636
# The obtained validation r2 score is :  0.6339923582801206
# The obtained validation r2 score is :  0.6299660004642684
# The obtained validation r2 score is :  0.6302533539125365
# The obtained validation r2 score is :  0.627488093493347
# The obtained validation r2 score is :  0.6369127622171727
# The obtained validation r2 score is :  0.6350885182456396
# The obtained validation r2 score is :  0.634101656823338
# The obtained validation r2 score is :  0.6306300620892435
# The obtained validation r2 score is :  0.6356995180091831
# The obtained validation r2 score is :  0.6323515439633389
# The obtained validation r2 score is :  0.6330237651271531
# The obtained validation r2 score is :  0.6352625631927628
# The obtained validation r2 score is :  0.6295620670084294
# The obtained validation r2 score is :  0.6310810454250371
# The obtained validation r2 score is :  0.6345044972312683
# The obtained validation r2 score is :  0.6255030463498237
# The obtained validation r2 score is :  0.6339370056354341
# The obtained validation r2 score is :  0.6350641959747916
# The obtained validation r2 score is :  0.6340275926991484
# The obtained validation r2 score is :  0.6334361563882056
# The obtained validation r2 score is :  0.632826046836622
# The obtained validation r2 score is :  0.6328826545945055
# The obtained validation r2 score is :  0.6372965729578631
# The obtained validation r2 score is :  0.6283759971379875
# The obtained validation r2 score is :  0.6369937749415129
# The obtained validation r2 score is :  0.6296663642360082
# The obtained validation r2 score is :  0.6398857299982372
# The obtained validation r2 score is :  0.6329341366064913
# The obtained validation r2 score is :  0.6324759789081256
# The obtained validation r2 score is :  0.6342165161459006
# The obtained validation r2 score is :  0.6342417385292871
# The obtained validation r2 score is :  0.6358635519110966
# The obtained validation r2 score is :  0.62714812460848
# The obtained validation r2 score is :  0.632551498827476
# The obtained validation r2 score is :  0.635884858980701
# The obtained validation r2 score is :  0.6329897097243495
# The obtained validation r2 score is :  0.6336106486604727
# The obtained validation r2 score is :  0.6347075332091527
# The obtained validation r2 score is :  0.6313347933659159
# The obtained validation r2 score is :  0.6366249499025677
# The obtained validation r2 score is :  0.6296312409243863
# The obtained validation r2 score is :  0.6306150042758822
# The obtained validation r2 score is :  0.6294061310937205
# The obtained validation r2 score is :  0.6325051709129149
# The obtained validation r2 score is :  0.6359194106495355
# The obtained validation r2 score is :  0.6349114037730237
# The obtained validation r2 score is :  0.6395186770134795
# The obtained validation r2 score is :  0.6325371637437244
# The obtained validation r2 score is :  0.6335979870641288
# The obtained validation r2 score is :  0.6319013367974684
# The obtained validation r2 score is :  0.6335040193819976
# The obtained validation r2 score is :  0.6367183791086699
# The obtained validation r2 score is :  0.6317235343348685
# The obtained validation r2 score is :  0.6303060033444641
# The obtained validation r2 score is :  0.6322217624990379
# The obtained validation r2 score is :  0.6327327867307417
# The obtained validation r2 score is :  0.6351223822144588
# The obtained validation r2 score is :  0.6376813273976615
# The obtained validation r2 score is :  0.6321488582198606
# The obtained validation r2 score is :  0.6323723036208728
# The obtained validation r2 score is :  0.6302545567532029
# The obtained validation r2 score is :  0.6337983815933793
# The obtained validation r2 score is :  0.6332340928428156
# The obtained validation r2 score is :  0.6314140308108516
# The obtained validation r2 score is :  0.6373777596384546
# The obtained validation r2 score is :  0.6325992370784532
# The obtained validation r2 score is :  0.6345040949951525
# The obtained validation r2 score is :  0.6253208426175465
# The obtained validation r2 score is :  0.6347877195282268
# The obtained validation r2 score is :  0.6341199758363747
# The obtained validation r2 score is :  0.6306561513289412
# The obtained validation r2 score is :  0.6322237319878623
# The obtained validation r2 score is :  0.6315595257942446
# The obtained validation r2 score is :  0.626031077395637
# The obtained validation r2 score is :  0.6379002747817638
# The obtained validation r2 score is :  0.6342911098188152
# The obtained validation r2 score is :  0.6332249247341479
# The obtained validation r2 score is :  0.6293040636466085
# The obtained validation r2 score is :  0.6306346153784944
# The obtained validation r2 score is :  0.6336438415130344
# The obtained validation r2 score is :  0.6315228964535983
# The obtained validation r2 score is :  0.6299399662693707
# The obtained validation r2 score is :  0.6308214117561726
# The obtained validation r2 score is :  0.6287828489991119
# The obtained validation r2 score is :  0.6321113370408076
# The obtained validation r2 score is :  0.6324759643992716
# The obtained validation r2 score is :  0.6331350234345436
# The obtained validation r2 score is :  0.6289761174057837
# The obtained validation r2 score is :  0.6306345055350865
# The obtained validation r2 score is :  0.6313009853469344
# The obtained validation r2 score is :  0.6318232185038439
# The obtained validation r2 score is :  0.6354856881989066
# The obtained validation r2 score is :  0.6256183303385847
# The obtained validation r2 score is :  0.6359119406311076
# The obtained validation r2 score is :  0.6324434653922995
# The obtained validation r2 score is :  0.6350352435822779
# The obtained validation r2 score is :  0.6303954431080014
# The obtained validation r2 score is :  0.6330494105304245
# The obtained validation r2 score is :  0.6364199747395786
# The obtained validation r2 score is :  0.6331726057592416
# The obtained validation r2 score is :  0.638574396995758
# The obtained validation r2 score is :  0.6306985064945472
# The obtained validation r2 score is :  0.6312250139801399
# The obtained validation r2 score is :  0.635167831432622
# The obtained validation r2 score is :  0.6364248458816676
# The obtained validation r2 score is :  0.6345746802643262
# The obtained validation r2 score is :  0.635232971826672
# The obtained validation r2 score is :  0.6372405131866465
# The obtained validation r2 score is :  0.6282909480397751
# The obtained validation r2 score is :  0.6320884680114027
# The obtained validation r2 score is :  0.6259926439099923
# The obtained validation r2 score is :  0.6306538199768561
# The obtained validation r2 score is :  0.6349498588838136
# The obtained validation r2 score is :  0.6340951659308327
# The obtained validation r2 score is :  0.6322835111021953
# The obtained validation r2 score is :  0.6356511510742913
# The obtained validation r2 score is :  0.6309730732060792
# The obtained validation r2 score is :  0.6286123941947104
# The obtained validation r2 score is :  0.632343619809555
# The obtained validation r2 score is :  0.6332147647891321
# The obtained validation r2 score is :  0.6369532412028154
# The obtained validation r2 score is :  0.6345233225275264
# The obtained validation r2 score is :  0.6259775965121847
# The obtained validation r2 score is :  0.6339852694975138
# The obtained validation r2 score is :  0.6344599043175354
# The obtained validation r2 score is :  0.6307735042509787
# The obtained validation r2 score is :  0.6321050947576293
# The obtained validation r2 score is :  0.6360929490063965
# The obtained validation r2 score is :  0.6337355764524071
# The obtained validation r2 score is :  0.6307289794244249
# The obtained validation r2 score is :  0.6275367795905509
# The obtained validation r2 score is :  0.6337028337570552
# The obtained validation r2 score is :  0.6297042096647754
# The obtained validation r2 score is :  0.632902438410687
# The obtained validation r2 score is :  0.6328203996876435
# The obtained validation r2 score is :  0.6354016474333596
# The obtained validation r2 score is :  0.6306363489445278
# The obtained validation r2 score is :  0.635529695274267
# The obtained validation r2 score is :  0.6316131990977871
# The obtained validation r2 score is :  0.6309205878075969
# The obtained validation r2 score is :  0.633176363415418
# The obtained validation r2 score is :  0.6250673563139865
# The obtained validation r2 score is :  0.631812595992608
# The obtained validation r2 score is :  0.6326757619948371
# The obtained validation r2 score is :  0.6335603138249238
# The obtained validation r2 score is :  0.6281314473085825
# The obtained validation r2 score is :  0.6294715787197654
# The obtained validation r2 score is :  0.6348514660982916
# The obtained validation r2 score is :  0.6305515564684396
# The obtained validation r2 score is :  0.6253287558490517
# The obtained validation r2 score is :  0.6300609797749479
# The obtained validation r2 score is :  0.6311877923791493
# The obtained validation r2 score is :  0.6333005141315406
# The obtained validation r2 score is :  0.6312367859676699
# The obtained validation r2 score is :  0.6294289195417524
# The obtained validation r2 score is :  0.63570138751498
# The obtained validation r2 score is :  0.634877772992313
# The obtained validation r2 score is :  0.6320853432510101
# The obtained validation r2 score is :  0.6389012819828114
# The obtained validation r2 score is :  0.6359496170444695
# The obtained validation r2 score is :  0.6268835343903925
# The obtained validation r2 score is :  0.6350126333247603
# The obtained validation r2 score is :  0.6316268611614454
# The obtained validation r2 score is :  0.6290544011981414
# The obtained validation r2 score is :  0.629792700614882
# The obtained validation r2 score is :  0.6307513278546708
# The obtained validation r2 score is :  0.6315729403433875
# The obtained validation r2 score is :  0.6310663902163377
# The obtained validation r2 score is :  0.6266153431316773
# The obtained validation r2 score is :  0.6316402724615363
# The obtained validation r2 score is :  0.6348661423431518
# The obtained validation r2 score is :  0.6292572593422103
# The obtained validation r2 score is :  0.6328021967095697
# The obtained validation r2 score is :  0.6353264867052668
# The obtained validation r2 score is :  0.6337749715375317
# The obtained validation r2 score is :  0.6344578978715014
# The obtained validation r2 score is :  0.6346068719774374
# The obtained validation r2 score is :  0.6363171232320977
# The obtained validation r2 score is :  0.6283126004506668
# The obtained validation r2 score is :  0.6342391997726596
# The obtained validation r2 score is :  0.6310391626482863
# The obtained validation r2 score is :  0.6288686602840718
# The obtained validation r2 score is :  0.6352562168043936
# The obtained validation r2 score is :  0.6325970927251944
# The obtained validation r2 score is :  0.6337237111935861
# The obtained validation r2 score is :  0.6374619247690132
# The obtained validation r2 score is :  0.6257393414997235
# The obtained validation r2 score is :  0.6300870530621874
# The obtained validation r2 score is :  0.6316243527329112
# The obtained validation r2 score is :  0.6311695381456949
# The obtained validation r2 score is :  0.6313758313020152
# The obtained validation r2 score is :  0.6340461980008933
# The obtained validation r2 score is :  0.6339079033800863
# The obtained validation r2 score is :  0.6321198935871131
# The obtained validation r2 score is :  0.6268469722769158
# The obtained validation r2 score is :  0.6366809996362567
# The obtained validation r2 score is :  0.6343619141445469
# The obtained validation r2 score is :  0.6353191551026415
# The obtained validation r2 score is :  0.6355825680482003
# The obtained validation r2 score is :  0.6376697121076453
# The obtained validation r2 score is :  0.6314150374568906
# The obtained validation r2 score is :  0.6341915252364425
# The obtained validation r2 score is :  0.6345209186681405
# The obtained validation r2 score is :  0.6332999009609046
# The obtained validation r2 score is :  0.631673204463615
# The obtained validation r2 score is :  0.6367161975218675
# The obtained validation r2 score is :  0.6309696235119802
# The obtained validation r2 score is :  0.6310593923893928
# The obtained validation r2 score is :  0.6362128040674753
# The obtained validation r2 score is :  0.6355862965922288
# The obtained validation r2 score is :  0.6306095069020773
# The obtained validation r2 score is :  0.6354333939889604
# The obtained validation r2 score is :  0.6300257954513034
# The obtained validation r2 score is :  0.6372967682571701
# The obtained validation r2 score is :  0.629893716682773
# The obtained validation r2 score is :  0.63320185374293
# The obtained validation r2 score is :  0.6352688558667114
# The obtained validation r2 score is :  0.6328309986327153
# The obtained validation r2 score is :  0.6345805346609188
# The obtained validation r2 score is :  0.6346582201673567
# The obtained validation r2 score is :  0.6355278199249963
# The obtained validation r2 score is :  0.6322784472654688
# The obtained validation r2 score is :  0.6382987166534281
# The obtained validation r2 score is :  0.6367650341468647
# The obtained validation r2 score is :  0.6358600091203869
# The obtained validation r2 score is :  0.6333388698689126
# The obtained validation r2 score is :  0.6351708476174968
# The obtained validation r2 score is :  0.6301093445743999
# The obtained validation r2 score is :  0.6311913106156113
# The obtained validation r2 score is :  0.6317407686250472
# The obtained validation r2 score is :  0.6308144570067435
# The obtained validation r2 score is :  0.6350419803661128
# The obtained validation r2 score is :  0.6314124491603607
# The obtained validation r2 score is :  0.6347594544233173
# The obtained validation r2 score is :  0.6252384242264908
# The obtained validation r2 score is :  0.6324376673574144
# The obtained validation r2 score is :  0.6305651021569146
# The obtained validation r2 score is :  0.6361225833632729
# The obtained validation r2 score is :  0.6344289635604601
# The obtained validation r2 score is :  0.6369006963666723
# The obtained validation r2 score is :  0.632881387964889
# The obtained validation r2 score is :  0.6343591456469663
# The obtained validation r2 score is :  0.6348808570131306
# The obtained validation r2 score is :  0.6311936430521086
# The obtained validation r2 score is :  0.6335333466504663
# The obtained validation r2 score is :  0.6353727727062068
# The obtained validation r2 score is :  0.6286928629958654
# The obtained validation r2 score is :  0.633034193068952
# The obtained validation r2 score is :  0.6284737844829988
# The obtained validation r2 score is :  0.6309214372094967
# The obtained validation r2 score is :  0.6361532122638359
# The obtained validation r2 score is :  0.6344206053075664
# The obtained validation r2 score is :  0.6348138849028755
# The obtained validation r2 score is :  0.6354894603010794
# The obtained validation r2 score is :  0.6318469116671708
# The obtained validation r2 score is :  0.6328104955140426
# The obtained validation r2 score is :  0.634709986553819
# The obtained validation r2 score is :  0.625224494723055
# The obtained validation r2 score is :  0.6314225805507425
# The obtained validation r2 score is :  0.6350058374517988
# The obtained validation r2 score is :  0.6292407267345864
# The obtained validation r2 score is :  0.626241349005417
# The obtained validation r2 score is :  0.6230433435976106
# The obtained validation r2 score is :  0.6324353466637952
# The obtained validation r2 score is :  0.6319521460422732
# The obtained validation r2 score is :  0.6265328017222489
# The obtained validation r2 score is :  0.6327640040232838
# The obtained validation r2 score is :  0.6258979358322684
# The obtained validation r2 score is :  0.6304185631668393
# The obtained validation r2 score is :  0.6293193714230565
# The obtained validation r2 score is :  0.624995585340559
# The obtained validation r2 score is :  0.624828960313965
# The obtained validation r2 score is :  0.6304736671087718
# The obtained validation r2 score is :  0.6307840740012507
# The obtained validation r2 score is :  0.6289604779292954
# The obtained validation r2 score is :  0.6268909610377058
# The obtained validation r2 score is :  0.6362792511188566
# The obtained validation r2 score is :  0.6362734439994296
# The obtained validation r2 score is :  0.6319976149844357
# The obtained validation r2 score is :  0.6272043755671332
# The obtained validation r2 score is :  0.6311404087324266
# The obtained validation r2 score is :  0.6313367165254592
# The obtained validation r2 score is :  0.6225620950476682
# The obtained validation r2 score is :  0.6317366305868238
# The obtained validation r2 score is :  0.6374538696482077
# The obtained validation r2 score is :  0.6279988383299411
# The obtained validation r2 score is :  0.6280452433498808
# The obtained validation r2 score is :  0.6343187445509999
# The obtained validation r2 score is :  0.6348363213328677
# The obtained validation r2 score is :  0.6340565269756647
# The obtained validation r2 score is :  0.635035611406272
# The obtained validation r2 score is :  0.632205861235408
# The obtained validation r2 score is :  0.6273197234145436
# The obtained validation r2 score is :  0.6288963352245152
# The obtained validation r2 score is :  0.634636315436893
# The obtained validation r2 score is :  0.6321824257253917
# The obtained validation r2 score is :  0.6291627292897635
# The obtained validation r2 score is :  0.6307773909031458
# The obtained validation r2 score is :  0.6286509143667894
# The obtained validation r2 score is :  0.627088525763942
# The obtained validation r2 score is :  0.6340405613473978
# The obtained validation r2 score is :  0.632103994768457
# The obtained validation r2 score is :  0.6256801731977376
# The obtained validation r2 score is :  0.6311951672485252
# The obtained validation r2 score is :  0.6272041869571854
# The obtained validation r2 score is :  0.6270813830608911
# The obtained validation r2 score is :  0.6340521238803917
# The obtained validation r2 score is :  0.6345778428917627
# The obtained validation r2 score is :  0.6296207918258794
# The obtained validation r2 score is :  0.6369758130770007
# The obtained validation r2 score is :  0.6387164127904776
# The obtained validation r2 score is :  0.6346554602380228
# The obtained validation r2 score is :  0.628532288757068
# The obtained validation r2 score is :  0.6260602301540237
# The obtained validation r2 score is :  0.6377461372185758
# The obtained validation r2 score is :  0.6292204270330397
# The obtained validation r2 score is :  0.6330628195120143
# The obtained validation r2 score is :  0.6333139513439793
# The obtained validation r2 score is :  0.6317630983165119
# The obtained validation r2 score is :  0.6300886878034999
# The obtained validation r2 score is :  0.6251745282733521
# The obtained validation r2 score is :  0.6309970693951577
# The obtained validation r2 score is :  0.6326240447018499
# The obtained validation r2 score is :  0.6345952071575677
# The obtained validation r2 score is :  0.634185423308388
# The obtained validation r2 score is :  0.6301889015065822
# The obtained validation r2 score is :  0.6301203787719978
# The obtained validation r2 score is :  0.6256594444345037
# The obtained validation r2 score is :  0.6322431389589681
# The obtained validation r2 score is :  0.6349961648037641
# The obtained validation r2 score is :  0.6294161455257242
# The obtained validation r2 score is :  0.6303038547703115
# The obtained validation r2 score is :  0.6355469099060418
# The obtained validation r2 score is :  0.6334812962967102
# The obtained validation r2 score is :  0.6335549066086074
# The obtained validation r2 score is :  0.6387639740281724
# The obtained validation r2 score is :  0.6323888039860288
# The obtained validation r2 score is :  0.6271561373748237
# The obtained validation r2 score is :  0.6241598182403301
# The obtained validation r2 score is :  0.6355163973442128
# The obtained validation r2 score is :  0.629559105766735
# The obtained validation r2 score is :  0.625696579378433
# The obtained validation r2 score is :  0.6317554339008747
# The obtained validation r2 score is :  0.6331686833557966
# The obtained validation r2 score is :  0.6343614441975964
# The obtained validation r2 score is :  0.6329044180697945
# The obtained validation r2 score is :  0.6306751015032541
# The obtained validation r2 score is :  0.631818330722725
# The obtained validation r2 score is :  0.6324610295154537
# The obtained validation r2 score is :  0.633274150378327
# The obtained validation r2 score is :  0.6355432899479807
# The obtained validation r2 score is :  0.6339845639350172
# The obtained validation r2 score is :  0.635946099879671
# The obtained validation r2 score is :  0.6346444062641906
# The obtained validation r2 score is :  0.6396329441929928
# The obtained validation r2 score is :  0.63353653746356
# The obtained validation r2 score is :  0.6352450458602503
# The obtained validation r2 score is :  0.634638802232297
# The obtained validation r2 score is :  0.6335592423710793
# The obtained validation r2 score is :  0.625764200846637
# The obtained validation r2 score is :  0.6292167423610355
# The obtained validation r2 score is :  0.6306742778362864
# The obtained validation r2 score is :  0.6350949175309154
# The obtained validation r2 score is :  0.6343105195671626
# The obtained validation r2 score is :  0.6349021268014534
# The obtained validation r2 score is :  0.6342439982471395
# The obtained validation r2 score is :  0.6356952759626258
# The obtained validation r2 score is :  0.6300700566113229
# The obtained validation r2 score is :  0.6239419767671354
# The obtained validation r2 score is :  0.6343757115079838
# The obtained validation r2 score is :  0.6364415296446009
# The obtained validation r2 score is :  0.6340407725256035
# The obtained validation r2 score is :  0.634574923439603
# The obtained validation r2 score is :  0.6318825441863221
# The obtained validation r2 score is :  0.6337673950893261
# The obtained validation r2 score is :  0.6311037555067154
# The obtained validation r2 score is :  0.6330387457366005
# The obtained validation r2 score is :  0.6263522746376344
# The obtained validation r2 score is :  0.6384935712798747
# The obtained validation r2 score is :  0.6254587139695154
# The obtained validation r2 score is :  0.636638966965179
# The obtained validation r2 score is :  0.6354024996056064
# The obtained validation r2 score is :  0.6343471749689173
# The obtained validation r2 score is :  0.6251054669942622
# The obtained validation r2 score is :  0.6346075039266149
# The obtained validation r2 score is :  0.634908862433962
# The obtained validation r2 score is :  0.6335689498960679
# The obtained validation r2 score is :  0.6269994741348057
# The obtained validation r2 score is :  0.6264102103558229
# The obtained validation r2 score is :  0.6345148908497683
# The obtained validation r2 score is :  0.6277952553907219
# The obtained validation r2 score is :  0.63331787441063
# The obtained validation r2 score is :  0.6298097767156172
# The obtained validation r2 score is :  0.6265393476009378
# The obtained validation r2 score is :  0.6293569322367547
# The obtained validation r2 score is :  0.6301143026114068
# The obtained validation r2 score is :  0.6309735062768177
# The obtained validation r2 score is :  0.6354951910070783
# The obtained validation r2 score is :  0.6280431762017744
# The obtained validation r2 score is :  0.6326163578681687
# The obtained validation r2 score is :  0.627756606815803
# The obtained validation r2 score is :  0.6315413951696465
# The obtained validation r2 score is :  0.6287235210590254
# The obtained validation r2 score is :  0.6335603951179218
# The obtained validation r2 score is :  0.6325766882452522
# The obtained validation r2 score is :  0.6369584582796771
# The obtained validation r2 score is :  0.6324153113957933
# The obtained validation r2 score is :  0.6292750394738309
# The obtained validation r2 score is :  0.6325397423284406
# The obtained validation r2 score is :  0.6280795083350479
# The obtained validation r2 score is :  0.632953935136661
# The obtained validation r2 score is :  0.6373446881392753
# The obtained validation r2 score is :  0.6352753492062394
# The obtained validation r2 score is :  0.6233819500393679
# The obtained validation r2 score is :  0.6299377886190974
# The obtained validation r2 score is :  0.632791313619145
# The obtained validation r2 score is :  0.6372139331617477
# The obtained validation r2 score is :  0.6330026342855598
# The obtained validation r2 score is :  0.6380987112706252
# The obtained validation r2 score is :  0.632653004882586
# The obtained validation r2 score is :  0.6303671228510217
# The obtained validation r2 score is :  0.6290878267208294
# The obtained validation r2 score is :  0.6238426585019745
# The obtained validation r2 score is :  0.6290580907722466
# The obtained validation r2 score is :  0.6275428821688047
# The obtained validation r2 score is :  0.6313386059608261
# The obtained validation r2 score is :  0.6302015212234533
# The obtained validation r2 score is :  0.6308731401751341
# The obtained validation r2 score is :  0.6266236763553665
# The obtained validation r2 score is :  0.6300301402465615
# The obtained validation r2 score is :  0.6318276723545784
# The obtained validation r2 score is :  0.6342781519872495
# The obtained validation r2 score is :  0.6293443568966668
# The obtained validation r2 score is :  0.6308982816280306
# The obtained validation r2 score is :  0.6273730398835276
# The obtained validation r2 score is :  0.6316955715190028
# The obtained validation r2 score is :  0.628034814963627
# The obtained validation r2 score is :  0.6317373030091719
# The obtained validation r2 score is :  0.6315548084836602
# The obtained validation r2 score is :  0.6321244486036346
# The obtained validation r2 score is :  0.6302854243213549
# The obtained validation r2 score is :  0.6368521782700469
# The obtained validation r2 score is :  0.6339824544559346
# The obtained validation r2 score is :  0.6350283219763116
# The obtained validation r2 score is :  0.633252062934367
# The obtained validation r2 score is :  0.6319418330072476
# The obtained validation r2 score is :  0.6310817056590695
# The obtained validation r2 score is :  0.6332809271276119
# The obtained validation r2 score is :  0.6274238778384198
# The obtained validation r2 score is :  0.625902238276453
# The obtained validation r2 score is :  0.6249197622697349
# The obtained validation r2 score is :  0.6302216725267715
# The obtained validation r2 score is :  0.6347079987186092
# The obtained validation r2 score is :  0.6275786813572206
# The obtained validation r2 score is :  0.6336303091331239
# The obtained validation r2 score is :  0.6321606073265841
# The obtained validation r2 score is :  0.638460261879608
# The obtained validation r2 score is :  0.6351293782747307
# The obtained validation r2 score is :  0.6293804020643052
# The obtained validation r2 score is :  0.6302748033425944
# The obtained validation r2 score is :  0.6279753911717797
# The obtained validation r2 score is :  0.6306912714913402
# The obtained validation r2 score is :  0.6317071189604591
# The obtained validation r2 score is :  0.6318045935713497
# The obtained validation r2 score is :  0.6300505632822198
# The obtained validation r2 score is :  0.6336054523952285
# The obtained validation r2 score is :  0.6265209127494241
# The obtained validation r2 score is :  0.6370955799844014
# The obtained validation r2 score is :  0.6366470956328564
# The obtained validation r2 score is :  0.6268586457387193
# The obtained validation r2 score is :  0.6334261863494804
# The obtained validation r2 score is :  0.636249030211752
# The obtained validation r2 score is :  0.6341452951904497
# The obtained validation r2 score is :  0.6364479340474303
# The obtained validation r2 score is :  0.6329152766343681
# The obtained validation r2 score is :  0.6369009915941273
# The obtained validation r2 score is :  0.6258532086806337
# The obtained validation r2 score is :  0.631253599563993
# The obtained validation r2 score is :  0.6288574145437471
# The obtained validation r2 score is :  0.6343732196471198
# The obtained validation r2 score is :  0.6368259470352824
# The obtained validation r2 score is :  0.6328154767185366
# The obtained validation r2 score is :  0.6294483740432776
# The obtained validation r2 score is :  0.6252840915617353
# The obtained validation r2 score is :  0.630279481699244
# The obtained validation r2 score is :  0.6356270147070671
# The obtained validation r2 score is :  0.6297376284772508
# The obtained validation r2 score is :  0.6333896044224059
# The obtained validation r2 score is :  0.6289386609311686
# The obtained validation r2 score is :  0.6331155322610582
# The obtained validation r2 score is :  0.6363414759535402
# The obtained validation r2 score is :  0.6341415562559931
# The obtained validation r2 score is :  0.6329453525764847
# The obtained validation r2 score is :  0.6347745400149616
# The obtained validation r2 score is :  0.6307178396019923
# The obtained validation r2 score is :  0.6305242898515707
# The obtained validation r2 score is :  0.6336393811023627
# The obtained validation r2 score is :  0.6302356041706757
# The obtained validation r2 score is :  0.6307579030170443
# The obtained validation r2 score is :  0.6267713861948911
# The obtained validation r2 score is :  0.6273232107959414
# The obtained validation r2 score is :  0.6309004465761194
# The obtained validation r2 score is :  0.627244362142647
# The obtained validation r2 score is :  0.6267315215769658
# The obtained validation r2 score is :  0.6364645460957764
# The obtained validation r2 score is :  0.6325072943512968
# The obtained validation r2 score is :  0.6278394157672106
# The obtained validation r2 score is :  0.6250072672795013
# The obtained validation r2 score is :  0.6309925412222854
# The obtained validation r2 score is :  0.6279377713968859
# The obtained validation r2 score is :  0.6369629133353548
# The obtained validation r2 score is :  0.6324754019074937
# The obtained validation r2 score is :  0.6332429314623254
# The obtained validation r2 score is :  0.6255855921292726
# The obtained validation r2 score is :  0.6320351667159726
# The obtained validation r2 score is :  0.6308479292459566
# The obtained validation r2 score is :  0.6352965522215936
# The obtained validation r2 score is :  0.6277379341474995
# The obtained validation r2 score is :  0.6359704027669633
# The obtained validation r2 score is :  0.635735258226056
# The obtained validation r2 score is :  0.632858854904842
# The obtained validation r2 score is :  0.6314310782935849
# The obtained validation r2 score is :  0.6364661292154604
# The obtained validation r2 score is :  0.6256435086159732
# The obtained validation r2 score is :  0.634898802910542
# The obtained validation r2 score is :  0.6323030040828355
# The obtained validation r2 score is :  0.6328344083642816
# The obtained validation r2 score is :  0.63256345080054
# The obtained validation r2 score is :  0.6282083057653749
# The obtained validation r2 score is :  0.634028659128109
# The obtained validation r2 score is :  0.6263544925491356
# The obtained validation r2 score is :  0.6331089791880709
# The obtained validation r2 score is :  0.6254648024821889
# The obtained validation r2 score is :  0.6303494663284664
# The obtained validation r2 score is :  0.6341467053958384
# The obtained validation r2 score is :  0.6272403047416029
# The obtained validation r2 score is :  0.625195710562084
# The obtained validation r2 score is :  0.6309886150500077
# The obtained validation r2 score is :  0.631467948412248
# The obtained validation r2 score is :  0.6348057536926328
# The obtained validation r2 score is :  0.6312759471783184
# The obtained validation r2 score is :  0.6286921679969439
# The obtained validation r2 score is :  0.6316545013623116
# The obtained validation r2 score is :  0.6316147013724857
# The obtained validation r2 score is :  0.6283985266619678
# The obtained validation r2 score is :  0.627536469724481
# The obtained validation r2 score is :  0.6350427248676738
# The obtained validation r2 score is :  0.6359514161841318
# The obtained validation r2 score is :  0.6268996994570616
# The obtained validation r2 score is :  0.6291068168363818
# The obtained validation r2 score is :  0.6323060077319138
# The obtained validation r2 score is :  0.6233166169617549
# The obtained validation r2 score is :  0.62836018307347
# The obtained validation r2 score is :  0.628601893995586
# The obtained validation r2 score is :  0.6318363003340899
# The obtained validation r2 score is :  0.6283020663445866
# The obtained validation r2 score is :  0.6307978121017858
# The obtained validation r2 score is :  0.6387325277002529
# The obtained validation r2 score is :  0.6339386221239253
# The obtained validation r2 score is :  0.6306973558279144
# The obtained validation r2 score is :  0.6350839596920062
# The obtained validation r2 score is :  0.6362976376046328
# The obtained validation r2 score is :  0.6279569029366237
# The obtained validation r2 score is :  0.6392031956070673
# The obtained validation r2 score is :  0.6345537537271012
# The obtained validation r2 score is :  0.6276344049950332
# The obtained validation r2 score is :  0.6320352672474561
# The obtained validation r2 score is :  0.6330744652615226
# The obtained validation r2 score is :  0.6327651060894626
# The obtained validation r2 score is :  0.6333754084424169
# The obtained validation r2 score is :  0.6293303478384011
# The obtained validation r2 score is :  0.6309060942906246
# The obtained validation r2 score is :  0.6322574111798035
# The obtained validation r2 score is :  0.634327522164757
# The obtained validation r2 score is :  0.6364038036398532
# The obtained validation r2 score is :  0.6329010041404212
# The obtained validation r2 score is :  0.6350723952539699
# The obtained validation r2 score is :  0.6369221601427368
# The obtained validation r2 score is :  0.6352811189835609
# The obtained validation r2 score is :  0.6301902220078144
# The obtained validation r2 score is :  0.6381132171993167
# The obtained validation r2 score is :  0.6265617103557874
# The obtained validation r2 score is :  0.6262507196535128
# The obtained validation r2 score is :  0.6363438325234403
# The obtained validation r2 score is :  0.6341003336370145
# The obtained validation r2 score is :  0.6372569945409434
# The obtained validation r2 score is :  0.6313066057064657
# The obtained validation r2 score is :  0.6319064654140963
# The obtained validation r2 score is :  0.6335206422837972
# The obtained validation r2 score is :  0.6345261232424005
# The obtained validation r2 score is :  0.6316456772838327
# The obtained validation r2 score is :  0.6327376678247879
# The obtained validation r2 score is :  0.6344951725524004
# The obtained validation r2 score is :  0.6341093765683679
# The obtained validation r2 score is :  0.6310162305051497
# The obtained validation r2 score is :  0.6306531686521601
# The obtained validation r2 score is :  0.6345032597526818
# The obtained validation r2 score is :  0.6344694644488225
# The obtained validation r2 score is :  0.6240233359520546
# The obtained validation r2 score is :  0.6369277154692264
# The obtained validation r2 score is :  0.6332859223516041
# The obtained validation r2 score is :  0.6297565023122568
# The obtained validation r2 score is :  0.6334538730592133
# The obtained validation r2 score is :  0.6234685264037809
# The obtained validation r2 score is :  0.632057076706831
# The obtained validation r2 score is :  0.6260265719100968
# The obtained validation r2 score is :  0.6319610820166115
# The obtained validation r2 score is :  0.6372993030509381
# The obtained validation r2 score is :  0.6295534885348438
# The obtained validation r2 score is :  0.6289413682555706
# The obtained validation r2 score is :  0.6336630483053836
# The obtained validation r2 score is :  0.6353512022075191
# The obtained validation r2 score is :  0.6287393851587375
# The obtained validation r2 score is :  0.6298082563143945
# The obtained validation r2 score is :  0.6276586901089453
# The obtained validation r2 score is :  0.6367030779010973
# The obtained validation r2 score is :  0.6363747844078004
# The obtained validation r2 score is :  0.6303589655566675
# The obtained validation r2 score is :  0.6319235467750817
# The obtained validation r2 score is :  0.6317841527915629
# The obtained validation r2 score is :  0.6331434196132963
# The obtained validation r2 score is :  0.6289102102811495
# The obtained validation r2 score is :  0.6302332831176405
# The obtained validation r2 score is :  0.6275443342681312
# The obtained validation r2 score is :  0.631116291225989
# The obtained validation r2 score is :  0.6298124467341837
# The obtained validation r2 score is :  0.6393771914461838
# The obtained validation r2 score is :  0.6264860020027868
# The obtained validation r2 score is :  0.634692122861377
# The obtained validation r2 score is :  0.6324214952326619
# The obtained validation r2 score is :  0.6308632187312588
# The obtained validation r2 score is :  0.6342164537477071
# The obtained validation r2 score is :  0.6301918945055477
# The obtained validation r2 score is :  0.6297012666770996
# The obtained validation r2 score is :  0.6342537189691789
# The obtained validation r2 score is :  0.6326474117224148
# The obtained validation r2 score is :  0.6299891895778406
# The obtained validation r2 score is :  0.6327551099548339
# The obtained validation r2 score is :  0.6312703780651568
# The obtained validation r2 score is :  0.6334892189052348
# The obtained validation r2 score is :  0.6334819122080126
# The obtained validation r2 score is :  0.6300305130286382
# The obtained validation r2 score is :  0.628466037985011
# The obtained validation r2 score is :  0.6320006475713982
# The obtained validation r2 score is :  0.6288041286524515
# The obtained validation r2 score is :  0.6323934570548019
# The obtained validation r2 score is :  0.6314697085076573
# The obtained validation r2 score is :  0.6337710202923855
# The obtained validation r2 score is :  0.6349786295967011
# The obtained validation r2 score is :  0.6351787395124281
# The obtained validation r2 score is :  0.6328410235815769
# The obtained validation r2 score is :  0.6352419317354951
# The obtained validation r2 score is :  0.6312842082642336
# The obtained validation r2 score is :  0.63491402952003
# The obtained validation r2 score is :  0.6242208895067239
# The obtained validation r2 score is :  0.6350087740040116
# The obtained validation r2 score is :  0.635637818311052
# The obtained validation r2 score is :  0.6269438274552468
# The obtained validation r2 score is :  0.6222182218355808
# The obtained validation r2 score is :  0.6336677934894401
# The obtained validation r2 score is :  0.6294793578939432
# The obtained validation r2 score is :  0.6343667269697958
# The obtained validation r2 score is :  0.6339120421342663
# The obtained validation r2 score is :  0.6328526968837913
# The obtained validation r2 score is :  0.6333110340255088
# The obtained validation r2 score is :  0.629921243115176
# The obtained validation r2 score is :  0.6278505711419555
# The obtained validation r2 score is :  0.6314533047854042
# The obtained validation r2 score is :  0.6284656993984745
# The obtained validation r2 score is :  0.6242117921991458
# The obtained validation r2 score is :  0.6337182239773146
# The obtained validation r2 score is :  0.6293797184128758
# The obtained validation r2 score is :  0.6331959381953564
# The obtained validation r2 score is :  0.6342099386339394
# The obtained validation r2 score is :  0.6346666884590256
# The obtained validation r2 score is :  0.6278250944963626
# The obtained validation r2 score is :  0.6292330944972282
# The obtained validation r2 score is :  0.6347302642012257
# The obtained validation r2 score is :  0.6350534615905319
# The obtained validation r2 score is :  0.6278529426059928
# The obtained validation r2 score is :  0.6268007120002983
# The obtained validation r2 score is :  0.6373793998148123
# The obtained validation r2 score is :  0.6293015616017097
# The obtained validation r2 score is :  0.6271973780045544
# The obtained validation r2 score is :  0.6362211904048192
# The obtained validation r2 score is :  0.6314885826191673
# The obtained validation r2 score is :  0.6317141398607494
# The obtained validation r2 score is :  0.6365584617091533
# The obtained validation r2 score is :  0.6343149454642864
# The obtained validation r2 score is :  0.6366684697278332
# The obtained validation r2 score is :  0.6284913212221461
# The obtained validation r2 score is :  0.6307304968244136
# The obtained validation r2 score is :  0.6329984042215916
# The obtained validation r2 score is :  0.6377444314772699
# The obtained validation r2 score is :  0.6347791973513044
# The obtained validation r2 score is :  0.631832848739388
# The obtained validation r2 score is :  0.623641764661659
# The obtained validation r2 score is :  0.6314456448212866
# The obtained validation r2 score is :  0.6311907246342936
# The obtained validation r2 score is :  0.6306801696317802
# The obtained validation r2 score is :  0.6297520050248544
# The obtained validation r2 score is :  0.6330093861222508
# The obtained validation r2 score is :  0.6317470680028742
# The obtained validation r2 score is :  0.6316407878132556
# The obtained validation r2 score is :  0.6294226794085576
# The obtained validation r2 score is :  0.6313221761754996
# The obtained validation r2 score is :  0.6347399643982312
# The obtained validation r2 score is :  0.6271223360858167
# The obtained validation r2 score is :  0.6293535474572147
# The obtained validation r2 score is :  0.6360890108917023
# The obtained validation r2 score is :  0.6342608940489539
# The obtained validation r2 score is :  0.6374036319843459
# The obtained validation r2 score is :  0.6250592253262574
# The obtained validation r2 score is :  0.6326983649438076
# The obtained validation r2 score is :  0.6314352411894006
# The obtained validation r2 score is :  0.6367121645542748
# The obtained validation r2 score is :  0.6338308307622093
# The obtained validation r2 score is :  0.62936379031156
# The obtained validation r2 score is :  0.6332580077424448
# The obtained validation r2 score is :  0.6277749850537687
# The obtained validation r2 score is :  0.6357182936860621
# The obtained validation r2 score is :  0.6326661691079151
# The obtained validation r2 score is :  0.62890839950509
# The obtained validation r2 score is :  0.6242720792546266
# The obtained validation r2 score is :  0.632362783659773
# The obtained validation r2 score is :  0.6301020269723357
# The obtained validation r2 score is :  0.6242040870933092
# The obtained validation r2 score is :  0.6352267730793627
# The obtained validation r2 score is :  0.628246205178215
# The obtained validation r2 score is :  0.631276967107369
# The obtained validation r2 score is :  0.6254234285496578
# The obtained validation r2 score is :  0.6315390839000028
# The obtained validation r2 score is :  0.6274051706913182
# The obtained validation r2 score is :  0.6280151235739645
# The obtained validation r2 score is :  0.6344128301473054
# The obtained validation r2 score is :  0.6331785506167503
# The obtained validation r2 score is :  0.6271285971446946
# The obtained validation r2 score is :  0.633903327192122
# The obtained validation r2 score is :  0.626502469365412
# The obtained validation r2 score is :  0.6324273656142914
# The obtained validation r2 score is :  0.6252023325005378
# The obtained validation r2 score is :  0.6305503112798743
# The obtained validation r2 score is :  0.6315487081760314
# The obtained validation r2 score is :  0.6358567210397177
# The obtained validation r2 score is :  0.630808054974766

# %%
for x in results.x:
    print(x)
# Out:
# 0.022311098951506406
# 0.024242524864550277
# 0.5005532443822837
# 0.8587066270194157
# 0.04199888269541904
# 1760
# 14
# 483
# 1250

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/df/qjssdfqd3f52ltwv16hkg4kh0000gn/T/ipykernel_38372/962467392.py in <module>
# ----> 1 results
#
# NameError: name 'results' is not defined
